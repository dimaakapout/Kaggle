# %% [markdown]
# <a href="https://colab.research.google.com/github/dimaakapout/Kaggle/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('training_data.csv')

# %%
data.tail()
# Out:
#       Age BusinessTravel              Department  DistanceFromHome  Education  \
# 2641   22     Non-Travel                   Sales              18.0          2
# 2642   39  Travel_Rarely                   Sales               4.0          4
# 2643   36  Travel_Rarely  Research & Development               2.0          3
# 2644   39     Non-Travel  Research & Development               8.0          5
# 2645   24  Travel_Rarely                   Sales              10.0          2
#
#      EducationField  Gender                 JobRole MaritalStatus  \
# 2641      Marketing    Male         Sales Executive       Married
# 2642      Marketing  Female   Laboratory Technician        Single
# 2643        Medical  Female  Manufacturing Director      Divorced
# 2644        Medical  Female    Sales Representative       Married
# 2645      Marketing    Male  Manufacturing Director      Divorced
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 2641        97890.0                 1.0                 18            8.0
# 2642        26100.0                 7.0                 12            8.0
# 2643       175670.0                 5.0                 13            8.0
# 2644       188240.0                 6.0                 19            8.0
# 2645        23560.0                 0.0                 13            8.0
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 2641                 2                4.0                    3.0
# 2642                 0                9.0                    2.0
# 2643                 0                7.0                    6.0
# 2644                 1               10.0                    4.0
# 2645                 0                2.0                    5.0
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 2641               4                        1                     3          0
# 2642               4                        2                     2          0
# 2643               1                        0                     0          0
# 2644               3                        1                     2          0
# 2645               1                        0                     0          0

# %%
pandas_profiling.ProfileReport(data)
# Out:
# C:\conda2020\lib\site-packages\pandas_profiling\model\correlations.py:35: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sqrt(phi2corr / min((kcorr - 1.0), (rcorr - 1.0)))
# Tab(children=(HTML(value='<div id="overview-content" class="row variable spacing">\n    <div class="row">\n   …
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
YearsWithCurrManager - неадекватные значения
дубликаты 
неинформативный признак

# %%
num_data = data._get_numeric_data()
num_data.head()
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   36               5.0          3        54050.0                 4.0
# 1   45               3.0          3        60740.0                 0.0
# 2   51              23.0          3       192720.0                 9.0
# 3   47              15.0          4        65530.0                 0.0
# 4   34              21.0          3        57704.0                 3.0
#
#    PercentSalaryHike  StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                 14            8.0                 0               10.0
# 1                 14            8.0                 0                9.0
# 2                 20            8.0                 0               18.0
# 3                 15            8.0                 0                8.0
# 4                117            8.0                 1                7.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                    2.0               8                        7
# 1                    2.0               8                        3
# 2                    2.0              10                        2
# 3                    2.0               7                        7
# 4                    4.0               0                        0
#
#    YearsWithCurrManager  Attrition
# 0                   104          0
# 1                     1          0
# 2                     7          1
# 3                     7          0
# 4                     0          0

# %%
sns.distplot(num_data.Age[num_data.Attrition==0], label='Attrition=0')
sns.distplot(num_data.Age[num_data.Attrition==1], label='Attrition=1')
plt.legend()

# %%
sns.distplot(num_data.DistanceFromHome[num_data.Attrition==0], label='Attrition=0')
sns.distplot(num_data.DistanceFromHome[num_data.Attrition==1], label='Attrition=1')
plt.legend()

# %%
sns.distplot(num_data.MonthlyIncome[num_data.Attrition==0], label='Attrition=0')
sns.distplot(num_data.MonthlyIncome[num_data.Attrition==1], label='Attrition=1')
plt.legend()

# %%
sns.distplot(num_data.NumCompaniesWorked[num_data.Attrition==0], label='Attrition=0')
sns.distplot(num_data.NumCompaniesWorked[num_data.Attrition==1], label='Attrition=1')
plt.legend()

# %%
sns.distplot(num_data.Education[num_data.Attrition==0], label='Attrition=0')
sns.distplot(num_data.Education[num_data.Attrition==1], label='Attrition=1')
plt.legend()

# %%
sns.distplot(num_data.StockOptionLevel[num_data.Attrition==0], label='Attrition=0')#, norm_hist=True)
sns.distplot(num_data.StockOptionLevel[num_data.Attrition==1], label='Attrition=1')#, norm_hist=True)
plt.legend()

# %%
sns.distplot(num_data.TotalWorkingYears[num_data.Attrition==0], label='Attrition=0')#, norm_hist=True)
sns.distplot(num_data.TotalWorkingYears[num_data.Attrition==1], label='Attrition=1')#, norm_hist=True)
plt.legend()

# %% [markdown]
# Тут можно заметить, что чем больше трудовой стаж у человека, тем менее склонен он к увольнению. Справа видим, что люди со стажем более 40 лет более склонны к увольнению (вероятно по причине выхода на пенсию)

# %%
sns.distplot(num_data.TrainingTimesLastYear[num_data.Attrition==0], label='Attrition=1')
sns.distplot(num_data.TrainingTimesLastYear[num_data.Attrition==1], label='Attrition=0')
plt.legend()

# %%
sns.distplot(num_data.YearsAtCompany[num_data.Attrition==0], label='Attrition=1')
sns.distplot(num_data.YearsAtCompany[num_data.Attrition==1], label='Attrition=0')
plt.legend()

# %%
sns.distplot(num_data.YearsSinceLastPromotion[num_data.Attrition==0], label='Attrition=1')
sns.distplot(num_data.YearsSinceLastPromotion[num_data.Attrition==1], label='Attrition=0')
plt.legend()

# %%
sns.distplot(num_data.YearsWithCurrManager[num_data.Attrition==0], label='Attrition=1')
sns.distplot(num_data.YearsWithCurrManager[num_data.Attrition==1], label='Attrition=0')
plt.legend()
plt.xlim(0,25) # т.к. данные не адекватны
# Out:
# (0, 25)

# %%
data.drop_duplicates()
# Out:
#       Age BusinessTravel              Department  DistanceFromHome  Education  \
# 0      36  Travel_Rarely                   Sales               5.0          3
# 1      45  Travel_Rarely                   Sales               3.0          3
# 2      51  Travel_Rarely                   Sales              23.0          3
# 3      47  Travel_Rarely                   Sales              15.0          4
# 4      34  Travel_Rarely  Research & Development              21.0          3
# ...   ...            ...                     ...               ...        ...
# 2638   28  Travel_Rarely  Research & Development               1.0          4
# 2641   22     Non-Travel                   Sales              18.0          2
# 2642   39  Travel_Rarely                   Sales               4.0          4
# 2643   36  Travel_Rarely  Research & Development               2.0          3
# 2644   39     Non-Travel  Research & Development               8.0          5
#
#         EducationField  Gender                    JobRole MaritalStatus  \
# 0     Technical Degree    Male            Sales Executive        Single
# 1        Life Sciences    Male  Healthcare Representative        Single
# 2              Medical  Female         Research Scientist       Married
# 3            Marketing  Female          Research Director       Married
# 4              Medical  Female      Laboratory Technician      Divorced
# ...                ...     ...                        ...           ...
# 2638     Life Sciences    Male          Research Director        Single
# 2641         Marketing    Male            Sales Executive       Married
# 2642         Marketing  Female      Laboratory Technician        Single
# 2643           Medical  Female     Manufacturing Director      Divorced
# 2644           Medical  Female       Sales Representative       Married
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 0           54050.0                 4.0                 14            8.0
# 1           60740.0                 0.0                 14            8.0
# 2          192720.0                 9.0                 20            8.0
# 3           65530.0                 0.0                 15            8.0
# 4           57704.0                 3.0                117            8.0
# ...             ...                 ...                ...            ...
# 2638       100960.0                 5.0                 13            8.0
# 2641        97890.0                 1.0                 18            8.0
# 2642        26100.0                 7.0                 12            8.0
# 2643       175670.0                 5.0                 13            8.0
# 2644       188240.0                 6.0                 19            8.0
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0               10.0                    2.0
# 1                    0                9.0                    2.0
# 2                    0               18.0                    2.0
# 3                    0                8.0                    2.0
# 4                    1                7.0                    4.0
# ...                ...                ...                    ...
# 2638                 0                6.0                    2.0
# 2641                 2                4.0                    3.0
# 2642                 0                9.0                    2.0
# 2643                 0                7.0                    6.0
# 2644                 1               10.0                    4.0
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                  8                        7                   104          0
# 1                  8                        3                     1          0
# 2                 10                        2                     7          1
# 3                  7                        7                     7          0
# 4                  0                        0                     0          0
# ...              ...                      ...                   ...        ...
# 2638               4                        0                     3          1
# 2641               4                        1                     3          0
# 2642               4                        2                     2          0
# 2643               1                        0                     0          0
# 2644               3                        1                     2          0
#
# [2281 rows x 20 columns]

# %%
cat_data = data[data.duplicated(keep=False)][data.Age==31][data.Education==4]
cat_data.head()
# Out:
# C:\conda2020\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Age BusinessTravel              Department  DistanceFromHome  Education  \
# 45     31  Travel_Rarely  Research & Development              17.0          4
# 230    31  Travel_Rarely  Research & Development               3.0          4
# 615    31     Non-Travel  Research & Development               9.0          4
# 1073   31  Travel_Rarely  Research & Development               3.0          4
# 1302   31  Travel_Rarely  Research & Development              17.0          4
#
#      EducationField  Gender          JobRole MaritalStatus  MonthlyIncome  \
# 45    Life Sciences    Male  Human Resources        Single        42440.0
# 230   Life Sciences  Female  Sales Executive      Divorced        29090.0
# 615   Life Sciences  Female  Sales Executive        Single       147320.0
# 1073  Life Sciences  Female  Sales Executive      Divorced        29090.0
# 1302  Life Sciences    Male  Human Resources        Single        42440.0
#
#       NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 45                   9.0                 13            8.0                 0
# 230                  9.0                 14            8.0                 2
# 615                  0.0                 12            8.0                 0
# 1073                 9.0                 14            8.0                 2
# 1302                 9.0                 13            8.0                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 45                  8.0                    3.0               3
# 230                10.0                    2.0               5
# 615                10.0                    3.0               9
# 1073               10.0                    2.0               5
# 1302                8.0                    3.0               3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 45                          0                     2          0
# 230                         0                     1          0
# 615                         1                     7          0
# 1073                        0                     1          0
# 1302                        0                     2          0

# %%
cat_data = pd.concat([data.select_dtypes(include='object'), data.Attrition], axis=1)
cat_data.head()
# Out:
#   BusinessTravel              Department    EducationField  Gender  \
# 0  Travel_Rarely                   Sales  Technical Degree    Male
# 1  Travel_Rarely                   Sales     Life Sciences    Male
# 2  Travel_Rarely                   Sales           Medical  Female
# 3  Travel_Rarely                   Sales         Marketing  Female
# 4  Travel_Rarely  Research & Development           Medical  Female
#
#                      JobRole MaritalStatus  Attrition
# 0            Sales Executive        Single          0
# 1  Healthcare Representative        Single          0
# 2         Research Scientist       Married          1
# 3          Research Director       Married          0
# 4      Laboratory Technician      Divorced          0

# %%
sns.countplot(x='BusinessTravel',data=cat_data, hue='Attrition')

# %%
sns.countplot(x='Department',data=cat_data, hue='Attrition')

# %%
sns.countplot(x='EducationField',data=cat_data, hue='Attrition')

# %%
sns.countplot(x='Gender',data=cat_data, hue='Attrition')

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.countplot(x='JobRole',data=cat_data, hue='Attrition')

# %%
sns.countplot(x='MaritalStatus',data=cat_data, hue='Attrition')

# %%
f, ax = plt.subplots(figsize=(9,9))
sns.heatmap(num_data.corr(), 
           annot= True, cmap='coolwarm')

# %% [markdown]
# # BaseLine

# %%
from sklearn.model_selection import train_test_split


from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer

# %%
y = data.Attrition
X = pd.get_dummies(data.drop(labels='Attrition', axis=1))

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, y)

# %%
xtrain.shape, ytrain.shape, ytest.shape
# Out:
# ((1984, 39), (1984,), (662,))

# %% [markdown]
# ## 2.1 Логистическая регрессия

# %%
baseline_model = Pipeline([('scaler', StandardScaler()), 
                           ('logreg', LogisticRegression())])

# %%
baseline_model.fit(xtrain, ytrain)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logreg', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
roc_auc_score(ytest, baseline_model.predict(xtest))
# Out:
# 0.5491431866864394

# %% [markdown]
# так себе результат

# %% [markdown]
# ## 2.2 RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
roc_auc_score(ytest, rf_model.predict(xtest))
# Out:
# 0.8100986569245161

# %% [markdown]
# Уже лучше

# %% [markdown]
# ## 2.3 GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_model = GradientBoostingClassifier(n_estimators=900)

# %%
gb_model.fit(xtrain, ytrain)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=900,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
roc_auc_score(ytest, gb_model.predict(xtest))
# Out:
# 0.836730731896719
